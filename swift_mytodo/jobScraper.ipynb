# %%
#!pip install chalice
#!pip install langchain_community
# !pip install petl
# Out:
# Collecting petl
#   Using cached petl-1.7.15-py3-none-any.whl
# Installing collected packages: petl
# Successfully installed petl-1.7.15

# %%
import os
import boto3
from chalice import Chalice, AuthResponse, Rate
from chalicelib import auth, db
import pandas as pd
from apify_client import ApifyClient
from datetime import datetime
from opensearchpy import OpenSearch, helpers
import utils
app = Chalice(app_name='mytodo')
app.debug = True
_DB = None
_USER_DB = None
apify_client = ApifyClient(utils.load_specific_api_key(filename='credential.txt', key_name='apify_client_apikey') ) 

# Define locations as a global variable
locations = {"w+CAIQICIHVG9yb250bw==": "Toronto", "w+CAIQICIJVmFuY291dmVy": "Vancourver", "w+CAIQICIITW9udHJlYWw=": "Montreal"}

def get_job_data(uule, jt):
    run_input = {
        "csvFriendlyOutput": True,
        "includeUnfilteredResults": False,
        "maxConcurrency": 10,
        "maxPagesPerQuery": 4,
        "queries": f"https://www.google.com/search?ibp=htl;jobs&q={jt}&uule={uule}",
        "saveHtml": False,
        "saveHtmlToKeyValueStore": False,
    }

    actor_call = apify_client.actor('dan.scraper/google-jobs-scraper').call(run_input=run_input)
    dataset_items = apify_client.dataset(actor_call['defaultDatasetId']).list_items().items

    d = pd.DataFrame(dataset_items)
    d["query"] = jt
    d["location"] = locations[uule]
    d["run_time"] = str(datetime.now())

    return d

def save_to_es(df):
    host = 'search-swift-hire-dev-jfmldmym4cfbiwdhwmtuqq6ihy.us-west-2.es.amazonaws.com' #put your host here
    port = 443
    auth = ('swift', 'Hire123!') # For testing only. Don't store credentials in code.

    client = OpenSearch(
        hosts = [{'host': host, 'port': port}],
        http_compress = True, # enables gzip compression for request bodies
        http_auth = auth,
        use_ssl = True,
        ssl_assert_hostname = False,
        ssl_show_warn = False,
    )

    index_name = "swift_dev_felix_kelly_jobposts"

    if not client.indices.exists(index_name):
        client.indices.create(index=index_name)

    def doc_generator(df):
        for i, row in df.iterrows():
            doc = {
                "_index": index_name,
                "_source": row.to_dict(),
            }
            yield doc

    helpers.bulk(client, doc_generator(df))

    print("Data Saved to Elastic Search dashboard Done.")
    
# for demo purpose, s3 bucket change
# for regular routine use 
@app.schedule(Rate(24, unit=Rate.HOURS))
def every_24_hour(eve): # add event if using time schedule based
    position_df = pd.DataFrame()
    job_titles = ["Software Engineer",  "Data Engineer", "Data Scientist"]
    #job_titles = ["Software Engineer"]

    for uule in locations:
        print(locations[uule])
        for jt in job_titles:
            print(jt)
            d = get_job_data(uule, jt)
            position_df = pd.concat([position_df, d])

        print("="*30)
    position_df.drop(columns='thumbnail', inplace=True)
    print(position_df)
    print("start the opensearch part")
    save_to_es(position_df)

# %%
every_24_hour()
# Out:
# Toronto
# Software Engineer
# Data Engineer
# Data Scientist
# ==============================
# Vancourver
# Software Engineer
# Data Engineer
# Data Scientist
# ==============================
# Montreal
# Software Engineer
# Data Engineer
# Data Scientist
# ==============================
#              query  location                    run_time  \
# 0    Data Engineer   Toronto  2024-03-24 16:52:36.286463
# 1    Data Engineer   Toronto  2024-03-24 16:52:36.286463
# 2    Data Engineer   Toronto  2024-03-24 16:52:36.286463
# 3    Data Engineer   Toronto  2024-03-24 16:52:36.286463
# 4    Data Engineer   Toronto  2024-03-24 16:52:36.286463
# ..             ...       ...                         ...
# 25  Data Scientist  Montreal  2024-03-24 16:54:58.370755
# 26  Data Scientist  Montreal  2024-03-24 16:54:58.370755
# 27  Data Scientist  Montreal  2024-03-24 16:54:58.370755
# 28  Data Scientist  Montreal  2024-03-24 16:54:58.370755
# 29  Data Scientist  Montreal  2024-03-24 16:54:58.370755
#
#                                         title           companyName  \
# 0                          Lead Data Engineer  Royal Bank of Canada
# 1                               Data Engineer                EvenUp
# 2                           Sr. Data Engineer                    EY
# 3                  Intermediate Data Engineer          confidential
# 4                          Lead data engineer             MethodHub
# ..                                        ...                   ...
# 25           Data Scientist Product Analytics              Descript
# 26            Bilingual Senior Data Scientist           CMHC - SCHL
# 27  Director of Data Science – AI/ML - Hybrid     ISAAC Instruments
# 28                      Senior Data Scientist  McKesson Corporation
# 29                        Lead Data Scientist               Equifax
#
#                           via  \
# 0             via RBC Careers
# 1                via LinkedIn
# 2              via EY Careers
# 3            via Apex Systems
# 4                via LinkedIn
# ..                        ...
# 25                via The Org
# 26           via ZipRecruiter
# 27  via Smart Recruiters Jobs
# 28               via JobzMall
# 29        via Equifax Careers
#
#                                           description  \
# 0   Job Summary\n\nJob Description\n\nWhat is the ...
# 1   EvenUp is on a mission to ensure that injury v...
# 2   At EY, you’ll have the chance to build a caree...
# 3   Intermediate Data Engineer\nApex Systems is a ...
# 4   Note: Azure Data engineer Certification is hig...
# ..                                                ...
# 25  Our vision is to build the next generation pla...
# 26  Job Requisition ID: 10010\n\nPosition Status: ...
# 27  Company Description\n\nISAAC partners with Nor...
# 28  Are you a highly skilled and experienced data ...
# 29  Do you have a passion for being at the forefro...
#
#                                         jobHighlights  \
# 0   [{'items': ['Job Summary
#
# Job Description
#
# Wha...
# 1   [{'items': ['EvenUp is on a mission to ensure ...
# 2   [{'items': ['At EY, you’ll have the chance to ...
# 3   [{'items': ['Intermediate Data Engineer
# Apex S...
# 4   [{'items': ['Note: Azure Data engineer Certifi...
# ..                                                ...
# 25  [{'items': ['Our vision is to build the next g...
# 26  [{'items': ['Job Requisition ID: 10010
#
# Positi...
# 27  [{'items': ['Company Description
#
# ISAAC partne...
# 28  [{'items': ['Are you a highly skilled and expe...
# 29  [{'items': ['Do you have a passion for being a...
#
#                                          relatedLinks  \
# 0   [{'link': 'http://www.rbc.com/', 'text': 'rbc....
# 1   [{'link': 'https://www.google.com/search?sca_e...
# 2   [{'link': 'http://www.ey.com/', 'text': 'ey.co...
# 3   [{'link': 'https://www.google.com/search?sca_e...
# 4   [{'link': 'http://www.method-hub.com/', 'text'...
# ..                                                ...
# 25  [{'link': 'http://www.descript.com/', 'text': ...
# 26  [{'link': 'https://www.google.com/search?sca_e...
# 27  [{'link': 'http://www.isaac.ca/', 'text': 'isa...
# 28  [{'link': 'https://www.google.com/search?sca_e...
# 29  [{'link': 'https://www.google.com/search?sca_e...
#
#                                               extras  \
# 0                            [2 days ago, Full–time]
# 1                            [2 days ago, Full–time]
# 2                          [19 hours ago, Full–time]
# 3                           [5 days ago, Contractor]
# 4      [2 days ago, CA$65–CA$70 an hour, Contractor]
# ..                                               ...
# 25                       [Work from home, Full-time]
# 26                          [11 days ago, Full-time]
# 27                                       [Full-time]
# 28  [12 days ago, CA$107K–CA$165K a year, Full-time]
# 29                                       [Full-time]
#
#                                              metadata  \
# 0   {'postedAt': '2 days ago', 'scheduleType': 'Fu...
# 1   {'postedAt': '2 days ago', 'scheduleType': 'Fu...
# 2   {'postedAt': '19 hours ago', 'scheduleType': '...
# 3   {'postedAt': '5 days ago', 'scheduleType': 'Co...
# 4   {'postedAt': '2 days ago', 'scheduleType': 'Co...
# ..                                                ...
# 25  {'scheduleType': 'Full-time', 'workFromHome': ...
# 26  {'postedAt': '11 days ago', 'scheduleType': 'F...
# 27                      {'scheduleType': 'Full-time'}
# 28  {'postedAt': '12 days ago', 'scheduleType': 'F...
# 29                      {'scheduleType': 'Full-time'}
#
#                                             applyLink
# 0   {'title': '.nFg2eb{font-weight:500}.Bi6Ddc{fon...
# 1   {'title': 'Apply on LinkedIn', 'link': 'https:...
# 2   {'title': 'Apply on EY Careers', 'link': 'http...
# 3   {'title': 'Apply on Apex Systems', 'link': 'ht...
# 4   {'title': 'Apply on LinkedIn', 'link': 'https:...
# ..                                                ...
# 25  {'title': 'Apply on The Org', 'link': 'https:/...
# 26  {'title': 'Apply on ZipRecruiter', 'link': 'ht...
# 27  {'title': 'Apply on Smart Recruiters Jobs', 'l...
# 28  {'title': 'Apply directly on JobzMall', 'link'...
# 29  {'title': 'Apply on Equifax Careers', 'link': ...
#
# [120 rows x 12 columns]
# start the opensearch part
# Data Saved to Elastic Search dashboard Done.
